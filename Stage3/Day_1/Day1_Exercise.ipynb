# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatimalbasha/KAUST-Labs2026/blob/main/Stage3/Day_1/Day1_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # 👁️👁️ **PyTorch CNN from Scratch: Fashion-MNIST**
#
# **In this notebook إن شاء الله you will learn how to:**
# 1. Build a dataset class for Fashion-MNIST
# 2. Build a small CNN model class
# 3. Training & Evaluation
# 4. Evaluate results through a confusion matrix

# %% [markdown]
# ## Very Quick Recap:
#
# | **Operation** | **Function** | **Purpose** | **Example Transformation** |
# |--------------|-------------|-------------|----------------------------|
# | **Flatten** | `.flatten()` | Convert tensor to (batch, features) | `(32, 3, 28, 28) → (32, 3*28*28)` |
# | **Squeeze** | `.squeeze()` | Remove dims of size 1 | `(1, 3, 28, 28) → (3, 28, 28)` |
# | **Unsqueeze** | `.unsqueeze(dim)` | Add a dim of size 1 | `(3, 28, 28) → (1, 3, 28, 28)` |
# | **Permute** | `.permute(dims)` | Change order of dimensions | `(32, 28, 28, 3) → (32, 3, 28, 28)` |
# | **View** | `.view(shape)` | Reshape freely | `(32, 28, 28, 3) → (32, 28*28*3)` |

# %% [markdown]
# ## Configurations

# %%
from IPython.display import clear_output
# !pip install torch torchvision matplotlib scikit-learn
clear_output()

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn #################
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms ########################
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # it is better to run CNNs with GPUs for faster computation
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 1️⃣ **Dataset Class**

# %% [markdown]
# ### 1.1 Transform functions
# A transform is a set of operations applied to each image when it’s loaded
#
# **Why?** → It is useful to:
#
# *   Convert input data to tensors
# *   Normalize data for model stabilization
# *   Augmentate training data for model robustness

# %%
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),   # light augmentation
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5]),
    # If they say "resize images" --> transforms.Resize((32, 32)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5]),
])

# %% [markdown]
# ### 1.2 Custom Class
# A Python class that implements:
# *   `__len__()` (how many samples)
# *   `__getitem__(i)` (how to return the i-th sample)
#
# **Why?** → Lets you have greater control over your dataset

# %%
class FashionMNISTCustom(Dataset):

    def __init__(self, root, train: bool, transform=None, download: bool = True):
        super().__init__()
        self.base = datasets.FashionMNIST(root=root, train=train, download=download) # This wraps the original FashionMNIST dataset from torchvision inside your custom class.
        self.transform = transform

    def __len__(self):
        return len(self.base) # This tells PyTorch how many samples exist.

    def __getitem__(self, idx): # This tells PyTorch how to fetch ONE sample.
        img, label = self.base[idx]  # img is a PIL image   # This gets one item from the original dataset.
        # img is usually a PIL image
        # label is an integer class id
        if self.transform is not None:
            img = self.transform(img)
        return {"image": img, "label": int(label), "index": int(idx)}

# %% [markdown]
# ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️
#
# If asked extra output like class name instead of class id
#
# You can add:
# class_name = self.base.classes[label]
#
# Then return it:
# return {"image": img, "label": int(label), "class_name": class_name, "index": int(idx)}

# %% [markdown]
# ### 1.3 Define datasets

# %%
train_ds = FashionMNISTCustom(root="./data", train=True,  download=True, transform=transform_train)
test_ds  = FashionMNISTCustom(root="./data", train=False, download=True, transform=transform_test)

# We got the label information from the Fashion-MNIST dataset page on Kaggle
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

print("\nTrain size:", len(train_ds), "| Test size:", len(test_ds))
# Out:
# Train size: 60000 | Test size: 10000

# %% [markdown]
# ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️
# If they say "use validation set"
#
# Split training:
#
# from torch.utils.data import random_split
#
# train_ds, val_ds = random_split(train_ds, [50000, 10000])

# %% [markdown]
# ### 1.4 Quick visualization
# Plotting a few sample images and labels from the dataset to ensure that the data was loaded correctly

# %%
fig, axes = plt.subplots(2, 6, figsize=(10, 4))
# If they ask: “Display 30 images”:
# fig, axes = plt.subplots(5, 6, figsize=(10, 8))
for ax in axes.ravel(): # Flattens the grid so you can loop easily over all 12 axes.
    idx = np.random.randint(0, len(train_ds))
    # If they say “no random, show first N”, change:
    # idx = i
    sample = train_ds[idx]
    x, y = sample["image"], sample["label"]
    # If dataset returns tuple not dict, change:
    # x, y = sample


    # unnormalize for display (approx)
    x_vis = (x * 0.5) + 0.5
    ax.imshow(x_vis.squeeze(0), cmap="gray")
    # If dataset is RGB (CIFAR-10), change:
    # ax.imshow(x_vis.permute(1,2,0))
    ax.set_title(class_names[y], fontsize=9)
    ax.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.5 DataLoaders
# A DataLoader wraps the dataset and creates batches of data handling batching, shuffling, parallel loading, and more
#
# **Why?** → Neural networks train efficiently on batches, not one image at a time.

# %%
batch_size = 128 # design choice: you could change this to 16, 32, 64...

train_loader = DataLoader(
    train_ds,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
    pin_memory=True
)

test_loader = DataLoader(
    test_ds,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# %%
# Inspecting one batch
batch = next(iter(train_loader))
xb = batch["image"]
yb = batch["label"]
print("Train loader batch sample X shape (input):", tuple(xb.shape), "\Train loader batch sample y shape (target):", tuple(yb.shape))
# Out:
# Train loader batch sample X shape (input): (128, 1, 28, 28) \Train loader batch sample y shape (target): (128,)
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipython-input-1379710323.py:5: SyntaxWarning: invalid escape sequence '\T'
#   print("Train loader batch sample X shape (input):", tuple(xb.shape), "\Train loader batch sample y shape (target):", tuple(yb.shape))

# %% [markdown]
# ## 2️⃣ **Model Class**
# Encapsulates the model architecture cleanly as a subclass of nn.Module that defines:
#
# layers in `__init__`
#
# forward computation in `forward()`

# %% [markdown]
# ![image.png](https://i.imgur.com/8XKBFBU.jpeg)

# %%
print(x.shape)
# Out:
# torch.Size([1, 28, 28])

# %%
class SimpleFashionCNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.features = nn.Sequential(

            # TRACE THE SHAPE OF THE TENSORS AS IT PASSES THROUGH THE CONV LAYERS TO AVOID SHAPE MISMATCH ERRORS
            # HOW? --> by using the output features formula shown above

            nn.Conv2d(1, 32, kernel_size=3, padding=1),  # [B,32,28,28]
            nn.ReLU(),
            nn.MaxPool2d(2),                             # [B,32,14,14]

            # TO-DO: Add second Conv2d layer (input: 32, output: 64, kernel: 3, padding: 1)
            nn.Conv2d(32, 64, kernel_size=3, padding=1),  # [B,64,14,14] #################
            nn.ReLU(),
            # TO-DO: Add MaxPool2d with kernel_size=2
            nn.MaxPool2d(2),                            # [B,64,7,7]
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            # TO-DO: Calculate input features (channels × height × width)
            # After 2 MaxPool2d(2): 28 → 14 → 7
            nn.Linear(64* 7 * 7, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # TO-DO: Pass x through features
        x = self.features(x)
        # TO-DO: Pass result through classifier
        x = self.classifier(x)
        return x

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. If dataset is RGB (CIFAR-10)

# Change first conv:
# nn.Conv2d(1, 32, ...)

# to:
# nn.Conv2d(3, 32, ...)

# %%
model = SimpleFashionCNN().to(device)

model # let's have a look at our model architecture
# Out:
# SimpleFashionCNN(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3136, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## 3️⃣ **Training & Evaluation**
# Code that repeatedly:
#
# 1.   passes inputs through the model (forward pass)
# 2.   computes loss
# 3.   computes gradients (backward pass)
# 4.   updates weights (optimizer step)
# 5.   evaluates on validation/test without updating weights
#
# **Training loop** is how the model learns, while the **validation loop** tells you how it performs on unseen data.

# %% [markdown]
# ### 3.1 Training function

# %%
def accuracy_from_logits(logits, labels):
    # TO-DO: Get predicted class indices
    # HINT: Use torch.argmax with dim=1
    preds = torch.argmax(logits, dim=1)
    # TO-DO: Calculate and return accuracy
    # HINT: Compare preds with labels, convert to float, mean, then .item()
    return (preds == labels).float().mean().item()

def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss, total_acc = 0.0, 0.0

    for batch in tqdm(loader):
        images, labels = batch['image'], batch['label']
        images, labels = images.to(device), labels.to(device)

        # TO-DO: Zero the gradients
        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        # TO-DO: Backward pass
        loss.backward()

        # TO-DO: Update parameters
        optimizer.step()

        total_loss += loss.item()
        total_acc += accuracy_from_logits(logits.detach(), labels)

    return total_loss / len(loader), total_acc / len(loader)

# %%
# 2. If binary classification
# Replace:
# preds = (logits > 0).long()

# with:
# preds = torch.argmax(logits, dim=1)

# %% [markdown]
# ### 3.2 Validation function

# %%
def evaluate(model, loader, criterion):
    model.eval()
    total_loss, total_acc = 0.0, 0.0

    with torch.no_grad():
        for batch in tqdm(loader):
            images, labels = batch['image'], batch['label']
            images, labels = images.to(device), labels.to(device)

            # TO-DO: Get model predictions
            logits = model(images)

            # TO-DO: Calculate loss
            # HINT: Use the criterion function
            loss = criterion(logits, labels)

            total_loss += loss.item()
            total_acc += accuracy_from_logits(logits, labels)

    return total_loss / len(loader), total_acc / len(loader)

# %%
# 1. If dataset returns tuple
# Change:
# images, labels = batch["image"], batch["label"]

# To:
# images, labels = batch

# %% [markdown]
# # The training loop computes predictions, loss, gradients via backpropagation, and updates weights using gradient descent, while the validation loop only performs forward passes without gradient updates.

# %% [markdown]
# ### 3.3 Setting hyperparameters + training the model

# %%
# Training setup
# TO-DO: Define loss criterion
# HINT: What loss function works for multi-class classification?
criterion = nn.CrossEntropyLoss()

# TO-DO: Set learning rate
learning_rate = 0.001 ###################################

# TO-DO: Define optimizer
# HINT: Pass model.parameters() and learning_rate
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate) ###################

# TO-DO: Set number of epochs
num_epochs = 10  # How many times to iterate through the dataset?

# Initialize history tracking
history = {"train_loss": [], "train_acc": [], "test_loss": [], "test_acc": []}

# Training loop
for epoch in range(num_epochs):
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)
    test_loss, test_acc = evaluate(model, test_loader, criterion)

    # Store history
    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["test_loss"].append(test_loss)
    history["test_acc"].append(test_acc)

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["test_loss"].append(test_loss)
    history["test_acc"].append(test_acc)

    print(f'Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# 100%|██████████| 469/469 [00:23<00:00, 20.20it/s]
# 100%|██████████| 79/79 [00:02<00:00, 38.03it/s]
# Epoch 1/10 - Train Loss: 0.5769, Train Acc: 0.7928, Test Loss: 0.3690, Test Acc: 0.8642
# 100%|██████████| 469/469 [00:17<00:00, 26.47it/s]
# 100%|██████████| 79/79 [00:02<00:00, 37.41it/s]
# Epoch 2/10 - Train Loss: 0.3635, Train Acc: 0.8690, Test Loss: 0.3213, Test Acc: 0.8837
# 100%|██████████| 469/469 [00:17<00:00, 27.36it/s]
# 100%|██████████| 79/79 [00:02<00:00, 36.27it/s]
# Epoch 3/10 - Train Loss: 0.3140, Train Acc: 0.8865, Test Loss: 0.2904, Test Acc: 0.8921
# 100%|██████████| 469/469 [00:18<00:00, 25.98it/s]
# 100%|██████████| 79/79 [00:02<00:00, 39.41it/s]
# Epoch 4/10 - Train Loss: 0.2838, Train Acc: 0.8971, Test Loss: 0.2774, Test Acc: 0.8975
# 100%|██████████| 469/469 [00:18<00:00, 25.56it/s]
# 100%|██████████| 79/79 [00:02<00:00, 35.92it/s]
# Epoch 5/10 - Train Loss: 0.2641, Train Acc: 0.9036, Test Loss: 0.2570, Test Acc: 0.9047
# 100%|██████████| 469/469 [00:17<00:00, 27.07it/s]
# 100%|██████████| 79/79 [00:02<00:00, 37.64it/s]
# Epoch 6/10 - Train Loss: 0.2455, Train Acc: 0.9100, Test Loss: 0.2523, Test Acc: 0.9080
# 100%|██████████| 469/469 [00:17<00:00, 26.26it/s]
# 100%|██████████| 79/79 [00:02<00:00, 38.15it/s]
# Epoch 7/10 - Train Loss: 0.2283, Train Acc: 0.9162, Test Loss: 0.2418, Test Acc: 0.9106
# 100%|██████████| 469/469 [00:18<00:00, 25.78it/s]
# 100%|██████████| 79/79 [00:02<00:00, 31.84it/s]
# Epoch 8/10 - Train Loss: 0.2158, Train Acc: 0.9207, Test Loss: 0.2421, Test Acc: 0.9090
# 100%|██████████| 469/469 [00:17<00:00, 27.01it/s]
# 100%|██████████| 79/79 [00:02<00:00, 37.35it/s]
# Epoch 9/10 - Train Loss: 0.2028, Train Acc: 0.9260, Test Loss: 0.2423, Test Acc: 0.9127
# 100%|██████████| 469/469 [00:17<00:00, 26.14it/s]
# 100%|██████████| 79/79 [00:02<00:00, 37.51it/s]
# Epoch 10/10 - Train Loss: 0.1930, Train Acc: 0.9291, Test Loss: 0.2258, Test Acc: 0.9203

# %%
# 1) If they tell you to use SGD instead of Adam:
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# 2) If accuracy is stuck / unstable
# Typical fixes:
# lower LR: 1e-3 → 1e-4
# or increase LR a bit: 1e-3 → 3e-3 (careful)

# %% [markdown]
# ### 3.4 Plotting accuracy and loss curves
# Graphs of training vs test loss/accuracy across epochs.
#
# **Why?** → Helps diagnose problems of overfitting/underfitting, making training behavior visible instead of guessing.

# %%
plt.figure(figsize=(15, 5))

epochs = len(history["train_loss"])

# Plot loss curve
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), history["train_loss"] , label="train_loss", marker='o')
plt.plot(range(1, epochs+1), history["test_loss"], label= "test_loss" , marker='o')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()

# Plot accuracy curve
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), history["train_acc"], label="train_acc", marker='o')
plt.plot(range(1, epochs+1), history["test_acc"] , label="test_acc", marker='o')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()

plt.show()

# %% [markdown]
# left plot: The model is learning and making fewer mistakes on both training and unseen data.
#
#
# right plot: The model is generalizing well — it performs almost the same on training and test.

# %% [markdown]
# ## 4️⃣ **Evaluation**

# %% [markdown]
# ### 4.1 Plot confusion matrix
#
# A table showing counts of:
#
# * true class (rows)
# * predicted class (columns)

# %%
def collect_preds(model, loader):
    """Collect all predictions and true labels for confusion matrix"""
    all_preds = []
    all_labels = []

    model.eval()
    with torch.no_grad():
        for batch in loader:
            images, labels = batch['image'], batch['label']
            images = images.to(device)

            # TO-DO: Get model predictions
            logits = model(images) # forward pass

            # TO-DO: Convert logits to predicted classes
            # HINT: Use argmax to get class indices
            preds = torch.argmax(logits, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    return np.array(all_preds), np.array(all_labels)

# Collect predictions
preds, labels = collect_preds(model, test_loader)

# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(labels, preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %% [markdown]
# # The diagonal (dark blue) = correct predictions
# # Everything off the diagonal = mistakes

# %%
# The diagonal shows correct predictions, while off-diagonal entries show class confusions.
# The model performs well on distinct classes (Trouser, Sandal, Bag) and struggles on
# visually similar classes (Shirt vs T-shirt, Coat vs Pullover).

# %%
# 1. If Dataset returns tuple
# Change:
# images, labels = batch['image'], batch['label']

# to:
# images, labels = batch


# 2. If binary classification
# Replace argmax with:
# preds = (logits > 0).long().squeeze()

# %% [markdown]
# ### 4.2 View ground truth and model prediction samples

# %%
@torch.no_grad() # --> diable greadient computation
def show_predictions(model, dataset, n=12):
    model.eval()
    fig, axes = plt.subplots(2, n//2, figsize=(15, 4))
    axes = axes.ravel()

    for i in range(n):
        sample = dataset[np.random.randint(0, len(dataset))]
        x, y = sample['image'], sample['label']
        logits = model(x.unsqueeze(0).to(device))
        pred = torch.argmax(logits, dim=1).item()

        x_vis = (x * 0.5) + 0.5
        axes[i].imshow(x_vis.squeeze(0), cmap="gray")
        axes[i].set_title(f"true = {class_names[y]}, pred = {class_names[pred]}", fontsize=9)
        axes[i].axis("off")

    plt.tight_layout()
    plt.show()

show_predictions(model, test_ds, n=12)

# %%
# 1. If dataset returns tuple
# Change:
# x, y = sample['image'], sample['label']

# to:
# x, y = sample


# 2. If dataset is RGB
# Change:
# axes[i].imshow(x_vis.squeeze(), cmap="gray")

# to:
# axes[i].imshow(x_vis.permute(1,2,0))
# Because RGB is [3, H, W].



# 3. If you want more images
# Change:
# show_predictions(model, test_ds, n=20)

# And grid auto-adjusts:
# 2 rows × 10 columns


# 4. If binary classification
# Change prediction:
# pred = (logits > 0).long().item()
# Instead of argmax.

# %% [markdown]
# ## 5️⃣ **Your turn**: optimize this pipeline through performing the following
#
# - add `BatchNorm2d` after conv layers
# - try a slightly deeper CNN (more channels)
# - add `RandomRotation(10)` augmentation
# - tune LR + epochs

# %% [markdown]
# ![its ez](https://tenor.com/view/easy-staples-that-was-easy-staples-easy-button-easy-button-gif-21815485.gif)

# %% [markdown]
# ### Contributed by: Farah Alshiha

# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)
